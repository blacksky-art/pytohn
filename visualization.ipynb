# %% [markdown]
# ALLEN JESTIN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

ds = pd.read_csv("car.csv")
ds.shape
# Out:
# (10000, 10)

# %%
ds.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
ds.head()
# Out:
#         Brand   Model  Year  Engine_Size Fuel_Type    Transmission  Mileage  \
# 0         Kia     Rio  2020          4.2    Diesel          Manual   289944
# 1   Chevrolet  Malibu  2012          2.0    Hybrid       Automatic     5356
# 2    Mercedes     GLA  2020          4.2    Diesel       Automatic   231440
# 3        Audi      Q5  2023          2.0  Electric          Manual   160971
# 4  Volkswagen    Golf  2003          2.6    Hybrid  Semi-Automatic   286618
#
#    Doors  Owner_Count  Price
# 0      3            5   8501
# 1      2            3  12092
# 2      4            2  11171
# 3      2            1  11780
# 4      3            3   2867

# %%
plt.scatter(ds['Brand'], ds['Price'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Brand')
plt.ylabel('Price')
 
plt.show()

# %%
plt.bar(ds['Model'], ds['Price'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('car model')
plt.ylabel('prize of engine')
 
# Adding the legends
plt.show()

# %%
plt.hist(ds['Mileage'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
plt.hist(ds['Price'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
sns.lineplot(x="Transmission", y="Price", data=ds)
plt.title('Lineplot')
 
plt.show()

# %%
plt.bar(ds['Transmission'], ds['Price'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('car transmission type')
plt.ylabel('price')
 
# Adding the legends
plt.show()

# %%
plt.bar(ds['Transmission'], ds['Price'])
 
plt.title("Bar Chart")
 
# Setting the X and Y labels
plt.xlabel('car transmission type')
plt.ylabel('price')
 
# Adding the legends
plt.show()

# %%
sns.barplot(x='Brand',y='Price', data=ds, 
            hue='Transmission')
 
plt.show()

# %%
sns.barplot(x='Brand',y='Price', data=ds, 
            hue='Fuel_Type')
 
plt.show()

# %%
sns.barplot(x='Year',y='Price', data=ds, 
            hue='Brand')
 
plt.show()
#the total amount for selling cars increases each year

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

ds = pd.read_csv("car.csv")
ds.shape
# Out:
# (10000, 10)

# %%
ds.isnull().sum()
# Out:
# Brand           0
# Model           0
# Year            0
# Engine_Size     0
# Fuel_Type       0
# Transmission    0
# Mileage         0
# Doors           0
# Owner_Count     0
# Price           0
# dtype: int64

# %%
ds.plot(x = 'Engine_Size', y = 'Mileage', kind='scatter')
# Out:
# <Axes: xlabel='Engine_Size', ylabel='Mileage'>

# %%
ds.Brand.value_counts().plot(kind= 'bar')
# Out:
# <Axes: xlabel='Brand'>

# %%
# Filter rows for 2023
ds_2023 = ds[ds['Year'] == 2023]

# Plot brand value counts for 2023
ds_2023['Brand'].value_counts().plot(kind='bar')
plt.title('Brand Distribution for 2023')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()
# audi has sold the most number of cars in the year 2023

# %%
ds_2023.plot(x = 'Engine_Size', y = 'Mileage', kind='scatter')
# Out:
# <Axes: xlabel='Engine_Size', ylabel='Mileage'>

# %%
sns.barplot(x='Brand',y='Price', data=ds_2023, 
            hue='Transmission')
 
plt.show()

# %%
plt.hist(ds_2023['Price'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
plt.hist(ds_2023['Brand'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
plt.hist(ds_2023['Mileage'])
 
plt.title("Histogram")
 
# Adding the legends
plt.show()

# %%
ds['Owner_Count'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
ds.plot(kind = 'box')
# Out:
# <Axes: >

# %%
ds['Price'].plot(kind = 'box')
# Out:
# <Axes: >

# %%
ds.boxplot(column='Price', by='Brand', figsize=(10, 6), rot=45)
plt.title('Price Distribution by Brand')
plt.suptitle('')  # Remove automatic subtitle
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()
'''There are outliers for price'''
# Out:
# 'There are outliers for price'

# %%
ds_2023.boxplot(column='Price', by='Brand', figsize=(10, 6), rot=45)
plt.title('Price Distribution by Brand')
plt.suptitle('')  # Remove automatic subtitle
plt.xlabel('Brand')
plt.ylabel('Price')
plt.show()

# %%
ds_2023.plot(x = 'Engine_Size', y = 'Mileage', kind='box')
# Out:
# <Axes: >

# %%
ds_2023.boxplot(column='Mileage', by='Brand', figsize=(12, 6), rot=45)
plt.title('Mileage by Brand')
plt.suptitle('')
plt.xlabel('Brand')
plt.ylabel('Mileage')
plt.show()

# %%
import matplotlib.pyplot as plt

ds_2023.boxplot(column='Mileage', by='Engine_Size')
plt.title('Mileage by Engine Size')
plt.suptitle('')  # optional: removes the automatic 'Boxplot grouped by' title
plt.xlabel('Engine Size')
plt.ylabel('Mileage')
plt.show()
#there are outliers in mileage for engine size 1.0 and 3.3

# %%
plt.pie(ds.Brand.value_counts(), labels = ds.Brand.unique())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(ds.Year.value_counts(), labels = ds.Year.unique())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(ds.Transmission.value_counts(), labels = ds.Transmission.unique())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(ds.Fuel_Type.value_counts(), labels = ds.Fuel_Type.unique())
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
ds.Fuel_Type.value_counts()
#no of cars based on fuel type
# Out:
# Fuel_Type
# Electric    2625
# Diesel      2512
# Hybrid      2453
# Petrol      2410
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 8))  # Set figure size before plotting
plt.pie(
    ds.Transmission.value_counts(), 
    labels=ds.Transmission.value_counts().index,  # safer than ds.Transmission.unique()
    autopct='%.2f%%'
)
plt.title('Transmission Type Distribution')
plt.show()
#distribution of cars based on transmission

# %%
# Compute correlation matrix
corr = ds.corr(numeric_only=True)  

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()
